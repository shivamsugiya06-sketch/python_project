# %%
def unit_converter():
    while True:
        print("\n Unit Converter App ")
        print("1. Weight Conversion")
        print("2. Time Conversion")
        print("3. Physics Converter")
        print("4. Exit")

        choice = input("Enter your choice: ")

        
        if choice == "1":
            print("\nWeight Conversion")
            print("1. Kilogram to Gram")
            print("2. Gram to Kilogram")
            print("3. Pound to Kilogram")
            print("4. Gram to Milligram")
            w_c = input("Enter conversion type: ")

            if w_c == "1":
                kg = float(input("Enter kg: "))
                print(f"{kg} kg = {kg*1000} g")
            elif w_c == "2":
                g = float(input("Enter grams: "))
                print(f"{g} g = {g/1000} kg")
            elif w_c == "3":
                p = float(input("Enter pounds: "))
                print(f"{p} p = {p*0.4536:.2f} kg")
            elif w_c == "4":
                g = float(input("Enter grams: "))
                print(f"{g} g = {g*1000} mg")
            else:
                print("Invalid choice!")

       
        elif choice == "2":
            print("\nTime Conversion")
            print("1. Hours to Minutes")
            print("2. Minutes to Seconds")
            t_c = input("Enter conversion type: ")

            if t_c == "1":
                h = float(input("Enter hours: "))
                print(f"{h} hr = {h*60} min")
            elif t_c == "2":
                m = float(input("Enter minutes: "))
                print(f"{m} min = {m*60} sec")
            else:
                print("Invalid choice!")

       
        elif choice == "3":
            print("\nPhysics Converter")
            print("1. Speed (m/s ↔ km/h)")
            print("2. Force (Newton ↔ Dyne)")
            print("3. Energy (Joule ↔ Calorie)")
            p_c = input("Enter conversion type: ")

            
            if p_c == "1":
                print("1. m/s to km/h")
                print("2. km/h to m/s")
                speed_choice = input("Enter conversion: ")
                if s_c == "1":
                    ms = float(input("Enter speed in m/s: "))
                    print(f"{ms} m/s = {ms*3.6:.2f} km/h")
                elif speed_choice == "2":
                    kmh = float(input("Enter speed in km/h: "))
                    print(f"{kmh} km/h = {kmh/3.6:.2f} m/s")
                else:
                    print("Invalid choice!")

           
            elif p_c == "2":
                print("1. Newton to Dyne")
                print("2. Dyne to Newton")
                force_choice = input("Enter conversion: ")
                if force_choice == "1":
                    n = float(input("Enter force in Newton: "))
                    print(f"{n} N = {n*1e5:.2f} dyne")
                elif force_choice == "2":
                    d = float(input("Enter force in Dyne: "))
                    print(f"{d} dyne = {d/1e5:.5f} N")
                else:
                    print("Invalid choice!")

            
            elif p_c == "3":
                print("1. Joule to Calorie")
                print("2. Calorie to Joule")
                energy_choice = input("Enter conversion: ")
                if energy_choice == "1":
                    j = float(input("Enter energy in Joule: "))
                    print(f"{j} J = {j/4.184:.2f} cal")
                elif energy_choice == "2":
                    cal = float(input("Enter energy in Calorie: "))
                    print(f"{cal} cal = {cal*4.184:.2f} J")
                else:
                    print("Invalid choice!")

            else:
                print("Invalid choice!")

        
        elif choice == "4":
            print("Exiting Converter App. Goodbye!")
            break

        else:
            print("Invalid choice! Please try again.")



if __name__ == "__main__":
    unit_converter()

# %%
3
