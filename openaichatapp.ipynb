# %%
import streamlit as st
import google.generativeai as genai
import pandas as pd
import matplotlib.pyplot as plt
with st.sidebar:
    st.title("MENU")
    section = st.radio("Choose Section:",
                       ["Profile", "Library", "Virtual Assistant"])
    st.write("Created by Shivam Kumar")
if section == "Profile":
    st.header("My Profile")
    st.write("Name: Shivam Kumar")
    st.write("Location: Jaipur, India")
    st.write("Skills: Python, Java, C, Generative AI")
    st.image(r"C:\Users\SHIVAM KUMAR\Downloads\python_practics\project\appnaa.jpg", caption="Profile Photo")
elif section == "Library":
    st.header("Tools")
    st.subheader("Bar Chart Example")
    chart_data = pd.DataFrame({"marks": [10, 20, 30, 10]})
    st.line_chart(chart_data)
    st.bar_chart(chart_data)
    st.subheader("Pie Chart Example")
    subject = ["Python", "C++", "Java"]
    marks = [20, 10, 5]
    fig, ax = plt.subplots()
    ax.pie(marks, labels=subject, autopct='%1.1f%%')
    st.pyplot(fig)
    st.title("Bubble Chart Example in Streamlit")
    x = [10, 20, 30, 40, 50]
    y = [5, 25, 15, 35, 10]
    sizes = [100, 200, 300, 500, 400]
    fig, ax = plt.subplots()
    ax.scatter(x, y, s=sizes, alpha=0.5)
    ax.set_title("Bubble Chart")
    ax.set_xlabel("X Values")
    ax.set_ylabel("Y Values")
    st.pyplot(fig)
    st.subheader("Simple Calculator")
    num1 = st.number_input("Enter first number", value=0)
    num2 = st.number_input("Enter second number", value=0)
    operation = st.selectbox("Choose operation", ["Add", "Subtract", "Multiply", "Divide"])
    if st.button("Calculate"):
        if operation == "Add":
            st.success(f"Result: {num1 + num2}")
        elif operation == "Subtract":
            st.success(f"Result: {num1 - num2}")
        elif operation == "Multiply":
            st.success(f"Result: {num1 * num2}")
        elif operation == "Divide":
            st.success(f"Result: {num1 / num2 if num2 != 0 else 'Error: Division by zero'}")

elif section == "Virtual Assistant":
    st.header("🤖 Virtual Assistant")
    st.text("Welcome to my dashboard!")

    API_KEY = "AIzaSyBL66sbtAe0abnt7CGeL58oaM3gnngeHv4"  
    genai.configure(api_key=API_KEY)
    model = genai.GenerativeModel("gemini-2.5-flash")

    user_msg = st.text_input("Enter your text :")
    if st.button("Send Message"):
        if user_msg.strip() != "":
            with st.spinner("Generating response..."):
                response = model.generate_content(user_msg)
            st.success("Bot Response:")
            st.write(response.text)
# Out:
# 2025-11-28 11:36:27.867 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 11:36:29.304
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\SHIVAM KUMAR\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-11-28 11:36:29.305 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 11:36:29.307 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 11:36:29.313 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 11:36:29.315 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 11:36:29.317 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 11:36:29.319 Session state does not function when running a script without `streamlit run`
# 2025-11-28 11:36:29.320 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 11:36:29.321 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 11:36:29.322 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 11:36:29.323 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 11:36:29.325 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 11:36:29.327 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 11:36:29.328 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 11:36:29.329 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 11:36:29.330 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 11:36:29.331 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 11:36:29.332 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 11:36:29.332 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-28 11:36:29.333 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\streamlit\elements\lib\image_utils.py:286, in image_to_url(image, width, clamp, channels, output_format, image_id)
#     285 try:
# --> 286     with open(image, "rb") as f:
#     287         image_data = f.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\SHIVAM KUMAR\\Downloads\\python_practics\\project\\appnaa.jpg'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 15
#      13     st.write("Location: Jaipur, India")
#      14     st.write("Skills: Python, Java, C, Generative AI")
# ---> 15     st.image(r"C:\Users\SHIVAM KUMAR\Downloads\python_practics\project\appnaa.jpg", caption="Profile Photo")
#      16 elif section == "Library":
#      17     st.header("Tools")
#
# File ~\anaconda3\Lib\site-packages\streamlit\runtime\metrics_util.py:444, in gather_metrics.<locals>.wrapped_func(*args, **kwargs)
#     442         _LOGGER.debug("Failed to collect command telemetry", exc_info=ex)
#     443 try:
# --> 444     result = non_optional_func(*args, **kwargs)
#     445 except RerunException as ex:
#     446     # Duplicated from below, because static analysis tools get confused
#     447     # by deferring the rethrow.
#     448     if tracking_activated and command_telemetry:
#
# File ~\anaconda3\Lib\site-packages\streamlit\elements\image.py:181, in ImageMixin.image(self, image, caption, width, use_column_width, clamp, channels, output_format, use_container_width)
#     178         image_width = WidthBehavior.MIN_IMAGE_OR_CONTAINER
#     180 image_list_proto = ImageListProto()
# --> 181 marshall_images(
#     182     self.dg._get_delta_path_str(),
#     183     image,
#     184     caption,
#     185     image_width,
#     186     image_list_proto,
#     187     clamp,
#     188     channels,
#     189     output_format,
#     190 )
#     191 return self.dg._enqueue("imgs", image_list_proto)
#
# File ~\anaconda3\Lib\site-packages\streamlit\elements\lib\image_utils.py:442, in marshall_images(coordinates, image, caption, width, proto_imgs, clamp, channels, output_format)
#     438 # We use the index of the image in the input image list to identify this image inside
#     439 # MediaFileManager. For this, we just add the index to the image's "coordinates".
#     440 image_id = "%s-%i" % (coordinates, coord_suffix)
# --> 442 proto_img.url = image_to_url(
#     443     image, width, clamp, channels, output_format, image_id
#     444 )
#
# File ~\anaconda3\Lib\site-packages\streamlit\elements\lib\image_utils.py:298, in image_to_url(image, width, clamp, channels, output_format, image_id)
#     295 if mimetype is None:
#     296     mimetype = "application/octet-stream"
# --> 298 url = runtime.get_instance().media_file_mgr.add(image, mimetype, image_id)
#     299 caching.save_media_data(image, mimetype, image_id)
#     300 return url
#
# File ~\anaconda3\Lib\site-packages\streamlit\runtime\__init__.py:28, in get_instance()
#      24 def get_instance() -> Runtime:
#      25     """Return the singleton Runtime instance. Raise an Error if the
#      26     Runtime hasn't been created yet.
#      27     """
# ---> 28     return Runtime.instance()
#
# File ~\anaconda3\Lib\site-packages\streamlit\runtime\runtime.py:156, in Runtime.instance(cls)
#     152 """Return the singleton Runtime instance. Raise an Error if the
#     153 Runtime hasn't been created yet.
#     154 """
#     155 if cls._instance is None:
# --> 156     raise RuntimeError("Runtime hasn't been created!")
#     157 return cls._instance
#
# RuntimeError: Runtime hasn't been created!
