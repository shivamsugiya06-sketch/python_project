# %%
import pyttsx3

# %%
pip install pyttsx3
# Out:
# Requirement already satisfied: pyttsx3 in c:\users\shivam kumar\anaconda3\lib\site-packages (2.99)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: comtypes in c:\users\shivam kumar\anaconda3\lib\site-packages (from pyttsx3) (1.4.13)
# Requirement already satisfied: pypiwin32 in c:\users\shivam kumar\anaconda3\lib\site-packages (from pyttsx3) (223)
# Requirement already satisfied: pywin32 in c:\users\shivam kumar\anaconda3\lib\site-packages (from pyttsx3) (308)

# %%
import pyttsx3

# %%
pip install SpeechRecognition
# Out:
# Requirement already satisfied: SpeechRecognition in c:\users\shivam kumar\anaconda3\lib\site-packages (3.14.4)
# Requirement already satisfied: typing-extensions in c:\users\shivam kumar\anaconda3\lib\site-packages (from SpeechRecognition) (4.15.0)
# Requirement already satisfied: standard-aifc in c:\users\shivam kumar\anaconda3\lib\site-packages (from SpeechRecognition) (3.13.0)
# Requirement already satisfied: audioop-lts in c:\users\shivam kumar\anaconda3\lib\site-packages (from SpeechRecognition) (0.2.2)
# Requirement already satisfied: standard-chunk in c:\users\shivam kumar\anaconda3\lib\site-packages (from standard-aifc->SpeechRecognition) (3.13.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install web-browser
# Out:
# Requirement already satisfied: web-browser in c:\users\shivam kumar\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: wheel in c:\users\shivam kumar\anaconda3\lib\site-packages (from web-browser) (0.45.1)
# Requirement already satisfied: requests==2.* in c:\users\shivam kumar\anaconda3\lib\site-packages (from web-browser) (2.32.3)
# Requirement already satisfied: selenium==4.* in c:\users\shivam kumar\anaconda3\lib\site-packages (from web-browser) (4.38.0)
# Requirement already satisfied: beautifulsoup4==4.* in c:\users\shivam kumar\anaconda3\lib\site-packages (from web-browser) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\shivam kumar\anaconda3\lib\site-packages (from beautifulsoup4==4.*->web-browser) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shivam kumar\anaconda3\lib\site-packages (from requests==2.*->web-browser) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shivam kumar\anaconda3\lib\site-packages (from requests==2.*->web-browser) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shivam kumar\anaconda3\lib\site-packages (from requests==2.*->web-browser) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shivam kumar\anaconda3\lib\site-packages (from requests==2.*->web-browser) (2025.11.12)
# Requirement already satisfied: trio<1.0,>=0.31.0 in c:\users\shivam kumar\anaconda3\lib\site-packages (from selenium==4.*->web-browser) (0.32.0)
# Requirement already satisfied: trio-websocket<1.0,>=0.12.2 in c:\users\shivam kumar\anaconda3\lib\site-packages (from selenium==4.*->web-browser) (0.12.2)
# Requirement already satisfied: typing_extensions<5.0,>=4.15.0 in c:\users\shivam kumar\anaconda3\lib\site-packages (from selenium==4.*->web-browser) (4.15.0)
# Requirement already satisfied: websocket-client<2.0,>=1.8.0 in c:\users\shivam kumar\anaconda3\lib\site-packages (from selenium==4.*->web-browser) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\shivam kumar\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium==4.*->web-browser) (24.3.0)
# Requirement already satisfied: sortedcontainers in c:\users\shivam kumar\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium==4.*->web-browser) (2.4.0)
# Requirement already satisfied: outcome in c:\users\shivam kumar\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium==4.*->web-browser) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\shivam kumar\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium==4.*->web-browser) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\shivam kumar\anaconda3\lib\site-packages (from trio<1.0,>=0.31.0->selenium==4.*->web-browser) (1.17.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\shivam kumar\anaconda3\lib\site-packages (from trio-websocket<1.0,>=0.12.2->selenium==4.*->web-browser) (1.3.2)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\shivam kumar\anaconda3\lib\site-packages (from urllib3[socks]<3.0,>=2.5.0->selenium==4.*->web-browser) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\shivam kumar\anaconda3\lib\site-packages (from cffi>=1.14->trio<1.0,>=0.31.0->selenium==4.*->web-browser) (2.21)
# Requirement already satisfied: h11<1,>=0.16.0 in c:\users\shivam kumar\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium==4.*->web-browser) (0.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyaudio
# Out:
# Requirement already satisfied: pyaudio in c:\users\shivam kumar\anaconda3\lib\site-packages (0.2.14)
# Note: you may need to restart the kernel to use updated packages.

# %%
import speech_recognition as sr
import os
import webbrowser
import pyttsx3   
engine = pyttsx3.init()
engine.setProperty("rate", 170)
engine.setProperty("volume", 1.0)
def speak(text):
    print("Assistant:", text)
    engine.say(text)
    engine.runAndWait()
def listen():
    r = sr.Recognizer()
    with sr.Microphone() as mic:
        print("Listening...")
        audio = r.listen(mic)
    try:
        return r.recognize_google(audio).lower()
    except:
        return ""
while True:
    command = listen()
    print("You said:", command)
    if "chrome" in command:
        speak("Opening Chrome")
        os.startfile(r"C:\Program Files\Google\Chrome\Application\chrome.exe")
    elif "notepad" in command:
        speak("Opening Notepad")
        os.system("notepad")
    elif "edge" in command:
        speak("Opening Microsoft Edge")
        os.startfile("msedge")
    elif "whatsapp" in command:
        speak("Opening WhatsApp Web")
        webbrowser.open("https://web.whatsapp.com")
    elif "youtube" in command:
        speak("Opening YouTube")
        webbrowser.open("https://www.youtube.com/")
    elif "exit" in command or "stop" in command:
        speak("Goodbye!")
        break
# Out:
# Listening...
# You said:
# Listening...
# You said: aap open whatsapp
# Assistant: Opening WhatsApp Web
# Listening...
# You said:
# Listening...
# You said: opening
# Listening...
# You said: chrome
# Assistant: Opening Chrome
# Listening...
# You said: open notepad
# Assistant: Opening Notepad
# Listening...
# You said:
# Listening...
# You said:
# Listening...
# You said: jacky laptop
# Listening...
# You said:
# Listening...
# You said:
# Listening...
# You said:
# Listening...
# You said:
# Listening...
